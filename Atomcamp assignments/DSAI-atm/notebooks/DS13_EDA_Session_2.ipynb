# %% [markdown]
# **Agenda**
#
# - Data type conversions
# - Missing values
# - Duplicates
# - Fuzzy Matching
# - Outliers
# - Binning

# %% [markdown]
# ### **Import libraries**

# %%
import pandas as pd

# %% [markdown]
# ### **Read dataset**

# %%
url = "https://docs.google.com/spreadsheets/d/1shAV45egx8eGlgey2eAC6zjMtnY82VJlPcyrVzUDlTI/export?format=csv"

# %%
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date         Street           City State  Zip Code
# 0  01/22/19 21:25  944 Walnut St         Boston    MA    2215.0
# 1  01/28/19 14:15   185 Maple St       Portland    OR   97035.0
# 2  01/17/19 13:33   538 Adams St  San Francisco    CA   94016.0
# 3  01/05/19 20:33    738 10th St    Los Angeles    CA   90001.0
# 4  01/25/19 11:59    387 10th St         Austin    TX   73301.0

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Data Type Converstions**

# %%
data.dtypes
# Out:
# Order ID            float64
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Street               object
# City                 object
# State                object
# Zip Code            float64
# dtype: object

# %% [markdown]
# Two functions for type conversions
#
# - To numeric
#   - (null or some text => NAN)
#   - convert it into float
#
# - Astype
#   - convert the column into any datatype
#   - limitation: it will throw error over the NULL values
#
# - to date_time
#   - coverts into date data types

# %% [markdown]
# Astype will return error on given column values
# ```
# Order ID
# "123"
# "345"
# "OFF-1234"
# "567"
# ```
# While, to_numeric will convert the values in to float and will convert the text data into NULL without throwing any error.
#
# ```
# Order ID
# 123.0
# 345.0
# NULL
# 567.0
# ``

# %%
#Assume order ID is in object

#astype
data["Order ID"].astype(float)

# when you are converting something into object/ or any other data type
# when you don't have any missing value in your columns
# Out:
# 0         141234.0
# 1         141235.0
# 2         141236.0
# 3         141237.0
# 4         141238.0
#             ...
# 185970    319666.0
# 185971    319667.0
# 185972    319668.0
# 185973    319669.0
# 185974    319670.0
# Name: Order ID, Length: 185975, dtype: float64

# %%
#object=> numerical
pd.to_numeric(data["Order ID"],errors="coerce")

# "text" in your column will be converted to NULL
# Will never throw error on missing or NULL values
# Out:
# 0         141234.0
# 1         141235.0
# 2         141236.0
# 3         141237.0
# 4         141238.0
#             ...
# 185970    319666.0
# 185971    319667.0
# 185972    319668.0
# 185973    319669.0
# 185974    319670.0
# Name: Order ID, Length: 185975, dtype: float64

# %%
data.dtypes
# Out:
# Order ID            float64
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Street               object
# City                 object
# State                object
# Zip Code            float64
# dtype: object

# %%
data["Order Date"].head(3)
# Out:
# 0    01/22/19 21:25
# 1    01/28/19 14:15
# 2    01/17/19 13:33
# Name: Order Date, dtype: object

# %%
2019/22/03 => datetime

"%y/%d/%m"

# %% [markdown]
# 1. %y => we can have 1,2,3,4 values for
# 2. No, changes are only saved in your dataframe (to_csv)

# %%
# # 1st
# column =
# # 2nd way
# inplace=True

# %%
# "25-August-21", format="%d-%B-%y"

# -exception handling

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"], format="%m/%d/%y %H:%M", errors="coerce")

# %%
data["Order Date"]
# Out:
# 0        2019-01-22 21:25:00
# 1        2019-01-28 14:15:00
# 2        2019-01-17 13:33:00
# 3        2019-01-05 20:33:00
# 4        2019-01-25 11:59:00
#                  ...
# 185970   2019-12-11 20:58:00
# 185971   2019-12-01 12:01:00
# 185972   2019-12-09 06:43:00
# 185973   2019-12-03 10:39:00
# 185974   2019-12-21 21:45:00
# Name: Order Date, Length: 185975, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# Order ID                   float64
# Product                     object
# Quantity Ordered           float64
# Price Each                 float64
# Order Date          datetime64[ns]
# Street                      object
# City                        object
# State                       object
# Zip Code                   float64
# dtype: object

# %% [markdown]
# ### **Duplicate values**

# %% [markdown]
# data load > duplicates check => view() to know whether you have to remove it or keep it
#
#
# - Remove
#     - When you are confirmed, that data is duplicated even the primary key value is duplicated
#     - Keep first when you need the old entries
#     - Keep last when you need the recent data
#
#
# - Keep /Don't remove
#     - when you are not sure about the context or you don't have primary key
#
# - Impute
#     - When you are sure that the duplicated value is error
#     - Impute it with placeholder or research about it

# %% [markdown]
# #### **Handle Duplicates**

# %%
data.duplicated().sum()
# Out:
# np.int64(289)

# %%
#conditional statement

data[data.duplicated()]
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 872     142071.0     AA Batteries (4-pack)               1.0        3.84
# 4106    145143.0  Lightning Charging Cable               1.0       14.95
# 5785    146765.0              Google Phone               1.0      600.00
# 6777    147707.0          Wired Headphones               1.0       11.99
# 8101    148984.0      USB-C Charging Cable               1.0       11.95
# ...          ...                       ...               ...         ...
# 180782  314675.0     AA Batteries (4-pack)               1.0        3.84
# 181333  315204.0          Wired Headphones               1.0       11.99
# 182114  315955.0           ThinkPad Laptop               1.0      999.99
# 182341  316173.0    AAA Batteries (4-pack)               1.0        2.99
# 184215  317971.0     AA Batteries (4-pack)               1.0        3.84
#
#                 Order Date            Street           City State  Zip Code
# 872    2019-01-17 23:02:00        131 2nd St         Boston    MA    2215.0
# 4106   2019-01-06 03:01:00  182 Jefferson St  San Francisco    CA   94016.0
# 5785   2019-01-21 11:23:00   918 Highland St  New York City    NY   10001.0
# 6777   2019-01-04 16:50:00        883 4th St         Dallas    TX   75001.0
# 8101   2019-01-08 17:36:00       562 14th St         Boston    MA    2215.0
# ...                    ...               ...            ...   ...       ...
# 180782 2019-12-26 09:01:00       927 13th St  San Francisco    CA   94016.0
# 181333 2019-12-12 12:41:00        680 6th St  San Francisco    CA   94016.0
# 182114 2019-12-26 17:28:00   588 Chestnut St        Seattle    WA   98101.0
# 182341 2019-12-22 22:44:00     907 Sunset St       Portland    OR   97035.0
# 184215 2019-12-17 18:39:00   250 Chestnut St  San Francisco    CA   94016.0
#
# [289 rows x 9 columns]

# %%
# find duplicates based on some primary key
data.duplicated(subset="Order ID").sum()

#
# data.drop_duplicates(subset="Order ID", inplace=True)
# Out:
# np.int64(7537)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Reset index
#
# because we have drop some duplicate rows.

# %%
data.reset_index(drop=True, inplace=True)

# %%
df = pd.DataFrame({"empID":[1,1,1,2,3,3,4],
                   "name":["Ahmad","Ahmad","Ahmad","Aliyan","Zia","Zia","Usman"],
                   "salary":[1500,1700,1800, 1800,1500,1500, 2000]})

# %%
df
# Out:
#    empID    name  salary
# 0      1   Ahmad    1500
# 1      1   Ahmad    1700
# 2      1   Ahmad    1800
# 3      2  Aliyan    1800
# 4      3     Zia    1500
# 5      3     Zia    1500
# 6      4   Usman    2000

# %%
# generalized appraoch, preffered for ML
#df.drop_duplicates()

# for analysis, you may have to work based on primary keys
#df.drop_duplicates(subset="empID",keep="first")

# keep recent entries, remove the old ones
df.drop_duplicates(subset="empID",keep="last")
# Out:
#    empID    name  salary
# 2      1   Ahmad    1800
# 3      2  Aliyan    1800
# 5      3     Zia    1500
# 6      4   Usman    2000

# %%
#df.drop_duplicates(subset="empID") #by default, it keeps the first unique record

df.drop_duplicates(subset="empID",keep="last")
# Out:
#    empID    name  salary
# 2      1   Ahmad    1800
# 3      2  Aliyan    1800
# 4      3     Zia    1500
# 5      4   Usman    2000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Missing value**

# %%
data.isnull().sum()
# Out:
# Order ID             1
# Product              1
# Quantity Ordered    51
# Price Each           6
# Order Date           1
# Street               1
# City                 1
# State                1
# Zip Code             1
# dtype: int64

# %%
# show the the complete blank rows
data[data.isnull().all(axis=1)]
# Out:
#        Order ID Product  Quantity Ordered  Price Each Order Date Street City  \
# 37097       NaN     NaN               NaN         NaN        NaT    NaN  NaN
#
#       State  Zip Code
# 37097   NaN       NaN

# %%
# show the rows where any column has missing value
data[data.isnull().any(axis=1)]
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 36771   176560.0          Wired Headphones               1.0         NaN
# 36785   176574.0              Google Phone               1.0         NaN
# 36918   176702.0     AA Batteries (4-pack)               1.0         NaN
# 37090   176866.0           ThinkPad Laptop               1.0         NaN
# 37097        NaN                       NaN               NaN         NaN
# 37166   176940.0  Lightning Charging Cable               NaN       14.95
# 37181   176955.0    AAA Batteries (4-pack)               NaN        2.99
# 37433   177194.0  Lightning Charging Cable               NaN       14.95
# 37561   177315.0          27in FHD Monitor               NaN      149.99
# 37581   177335.0          Wired Headphones               1.0         NaN
# 84212   222056.0      USB-C Charging Cable               NaN       11.95
# 84213   222057.0      USB-C Charging Cable               NaN       11.95
# 84214   222058.0              Google Phone               NaN      600.00
# 84215   222058.0      USB-C Charging Cable               NaN       11.95
# 84216   222059.0  Lightning Charging Cable               NaN       14.95
# 84217   222060.0    AAA Batteries (4-pack)               NaN        2.99
# 84218   222061.0    AAA Batteries (4-pack)               NaN        2.99
# 84219   222062.0      USB-C Charging Cable               NaN       11.95
# 84220   222063.0              20in Monitor               NaN      109.99
# 84221   222064.0  Lightning Charging Cable               NaN       14.95
# 84222   222065.0                    iPhone               NaN      700.00
# 84223   222065.0          Wired Headphones               NaN       11.99
# 84224   222066.0     AA Batteries (4-pack)               NaN        3.84
# 84225   222067.0          Wired Headphones               NaN       11.99
# 114304  251022.0      USB-C Charging Cable               NaN       11.95
# 114305  251023.0     AA Batteries (4-pack)               NaN        3.84
# 114306  251024.0  Apple Airpods Headphones               NaN      150.00
# 114307  251025.0  Lightning Charging Cable               NaN       14.95
# 114308  251026.0      USB-C Charging Cable               NaN       11.95
#     df.dropna()
#     # or Remove rows based on null values in specific column
#     df.dropna(subset = "CNIC")
#     ```
#
#     - **Drop the column or feature** — This needs good research of a specific column to understand its importance in the future. You can do this only when you are confident that this feature does not provide any useful information, for example, PassengerId feature in this dataset.
#
#     ```
#     # Remove columns that have more than 50% missing values
#     threshold = 0.5 * len (df)
#     df.dropna (thresh = threshold, axis=1)
#     ```
#
# - **Impute missing data** — In this technique, you can substitute the missing values or NaNs with the mean or median or mode of the same column.
#
#   - Constant (numerical or text columns)
#   - Mean  (numerical when there is no outlier)
#   - Median (numerical when there are outlier)
#   - Mode   (categorical, year, gender, department)
#   - Backward Fill  (categories, sequential, group wise)
#   - Forward Fill (categories, sequential, group wise)
#   - Interpolation  (time or sequential)
#   - K-Nearest Neighbors (KNN) imputation or model-based Imputation
#   (use when working with complex data)

# %% [markdown]
# - Constant
# ```
# df.fillna("constant")
# ```
#
#
#
#
# - Mean imputation for a numerical column 'age'
# ```
# df ['age'] = df ['age'].fillna(df['age'].mean())
# ```
#
# - Median imputation can be used:
# ```
# df ['age'] = df ['age'].fillna (df ['age'].median())
# ```
#
# - Mode imputation can be used:
# ```
# df ['Gender'] = df ['Gender'].fillna (df ['Gender'].mode()[0])
# ```
#
#
# - Backward Fill:
# ```
# df ['Column'] = df ['Column'].fillna(method='bfill')
# ```
#
# - Forward Fill:
# ```
# df ['Column'] = df ['Column'].fillna(method='ffill')
# ```
#
# - Interpolation:
# ```
# df ['Age'] = df ['Age'].interpolate()
# ```
#
# - Model Based:
# ```
# imputer = KNNImputer(n_neighbors=5)
# df ['Column']  = pd.DataFrame(imputer.fit_transform( ["Column"]), columns=Column)
# ```
#
#
# Data cleaning Guide: https://colab.research.google.com/drive/1koDm_qPc68VwjmD7CfcURMkxKNIbzztE?usp=sharing

# %%
data[data.isnull().all(axis=1)]
# Out:
#        Order ID Product  Quantity Ordered  Price Each Order Date Street City  \
# 37097       NaN     NaN               NaN         NaN        NaT    NaN  NaN
#
#       State  Zip Code
# 37097   NaN       NaN

# %%
data.dropna(subset="Order ID",inplace=True)

# %%
data.isnull().sum()
# Out:
# Order ID             0
# Product              0
# Quantity Ordered    50
# Price Each           5
# Order Date           0
# Street               0
# City                 0
# State                0
# Zip Code             0
# dtype: int64

# %%
data[data["Quantity Ordered"].isnull()]
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 37166   176940.0  Lightning Charging Cable               NaN       14.95
# 37181   176955.0    AAA Batteries (4-pack)               NaN        2.99
# 37433   177194.0  Lightning Charging Cable               NaN       14.95
# 37561   177315.0          27in FHD Monitor               NaN      149.99
# 84212   222056.0      USB-C Charging Cable               NaN       11.95
# 84213   222057.0      USB-C Charging Cable               NaN       11.95
# 84214   222058.0              Google Phone               NaN      600.00
# 84215   222058.0      USB-C Charging Cable               NaN       11.95
# 84216   222059.0  Lightning Charging Cable               NaN       14.95
# 84217   222060.0    AAA Batteries (4-pack)               NaN        2.99
# 84218   222061.0    AAA Batteries (4-pack)               NaN        2.99
# 84219   222062.0      USB-C Charging Cable               NaN       11.95
sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          5
# Order Date          0
# Street              0
# City                0
# State               0
# Zip Code            0
# dtype: int64

# %%
data[data["Price Each"].isnull()]
# Out:
#        Order ID                Product  Quantity Ordered  Price Each  \
# 36771  176560.0       Wired Headphones               1.0         NaN
# 36785  176574.0           Google Phone               1.0         NaN
# 36918  176702.0  AA Batteries (4-pack)               1.0         NaN
# 37090  176866.0        ThinkPad Laptop               1.0         NaN
# 37581  177335.0       Wired Headphones               1.0         NaN
#
#                Order Date         Street           City State  Zip Code
# 36771 2019-04-12 14:38:00  669 Spruce St    Los Angeles    CA   90001.0
# 36785 2019-04-03 19:42:00     20 Hill St    Los Angeles    CA   90001.0
# 36918 2019-04-23 19:44:00  896 Sunset St        Seattle    WA   98101.0
# 37090 2019-04-02 11:42:00    338 West St  New York City    NY   10001.0
# 37581 2019-04-14 21:59:00    95 South St  New York City    NY   10001.0

# %%
data[["Product","Price Each"]].value_counts(dropna=False)
# Out:
# Product                     Price Each
# USB-C Charging Cable        11.95          21859
# Lightning Charging Cable    14.95          21610
# AAA Batteries (4-pack)      2.99           20612
# AA Batteries (4-pack)       3.84           20557
# Wired Headphones            11.99          18847
# Apple Airpods Headphones    150.00         15525
# Bose SoundSport Headphones  99.99          13298
# 27in FHD Monitor            149.99          7498
# 27in 4K Gaming Monitor      389.99          6225
# 34in Ultrawide Monitor      379.99          6174
# Google Phone                600.00          6163
# iPhone                      700.00          5803
# Flatscreen TV               300.00          4794
# Macbook Pro Laptop          1700.00         4720
# ThinkPad Laptop             999.99          4125
# 20in Monitor                109.99          4098
# LG Washing Machine          600.00           666
# Google PHONE.               600.00           664
# LG Dryer                    600.00           646
# GOOGLE. PHONE               600.00           616
# i-Phone                     700.00           544
# iphone.                     700.00           287
# I Phone                     700.00           102
# google phoone               600.00           102
# iphone                      700.00            99
# Google-Phone                600.00            24
# google phone                600.00             8
# google Phone                600.00             7
# IPHONE                      700.00             4
# Wired Headphones            NaN                2
# ASUS Gaming Laptop          4800.00            1
# AA Batteries (4-pack)       NaN                1
# IPhone                      700.00             1
# Google Phone                NaN                1
# ThinkPad Laptop             NaN                1
# Macbook Pro Laptop          99999999.00        1
# Name: count, dtype: int64

# %%
data.sort_values(by="Product",inplace=True)

# %%
data.head()
# Out:
#         Order ID       Product  Quantity Ordered  Price Each  \
# 143165  278775.0  20in Monitor               1.0      109.99
# 26993   167149.0  20in Monitor               1.0      109.99
# 117149  253767.0  20in Monitor               1.0      109.99
# 117158  253776.0  20in Monitor               1.0      109.99
# 117183  253801.0  20in Monitor               1.0      109.99
#
#                 Order Date          Street           City State  Zip Code
# 143165 2019-10-13 12:00:00  400 Hickory St  San Francisco    CA   94016.0
# 26993  2019-03-04 01:59:00   241 Meadow St  San Francisco    CA   94016.0
# 117149 2019-09-17 22:33:00     861 Main St        Atlanta    GA   30301.0
# 117158 2019-09-13 22:11:00     370 Main St    Los Angeles    CA   90001.0
# 117183 2019-09-28 09:53:00     446 Lake St        Seattle    WA   98101.0

# %%
data[data["Price Each"].isnull()]
# Out:
#        Order ID                Product  Quantity Ordered  Price Each  \
# 36918  176702.0  AA Batteries (4-pack)               1.0         NaN
# 36785  176574.0           Google Phone               1.0         NaN
# 37090  176866.0        ThinkPad Laptop               1.0         NaN
# 37581  177335.0       Wired Headphones               1.0         NaN
# 36771  176560.0       Wired Headphones               1.0         NaN
#
#                Order Date         Street           City State  Zip Code
# 36918 2019-04-23 19:44:00  896 Sunset St        Seattle    WA   98101.0
# 36785 2019-04-03 19:42:00     20 Hill St    Los Angeles    CA   90001.0
# 37090 2019-04-02 11:42:00    338 West St  New York City    NY   10001.0
# 37581 2019-04-14 21:59:00    95 South St  New York City    NY   10001.0
# 36771 2019-04-12 14:38:00  669 Spruce St    Los Angeles    CA   90001.0

# %%
data.reset_index(drop=True,inplace=True)

# %%
data[data["Price Each"].isnull()]
# Out:
#         Order ID                Product  Quantity Ordered  Price Each  \
# 26873   176702.0  AA Batteries (4-pack)               1.0         NaN
# 101341  176574.0           Google Phone               1.0         NaN
# 136306  176866.0        ThinkPad Laptop               1.0         NaN
# 165083  177335.0       Wired Headphones               1.0         NaN
# 165539  176560.0       Wired Headphones               1.0         NaN
#
#                 Order Date         Street           City State  Zip Code
# 26873  2019-04-23 19:44:00  896 Sunset St        Seattle    WA   98101.0
# 101341 2019-04-03 19:42:00     20 Hill St    Los Angeles    CA   90001.0
# 136306 2019-04-02 11:42:00    338 West St  New York City    NY   10001.0
# 165083 2019-04-14 21:59:00    95 South St  New York City    NY   10001.0
# 165539 2019-04-12 14:38:00  669 Spruce St    Los Angeles    CA   90001.0

# %%
data.loc[26870:26875,["Product","Price Each"]]
# Out:
#                      Product  Price Each
# 26870  AA Batteries (4-pack)        3.84
# 26871  AA Batteries (4-pack)        3.84
# 26872  AA Batteries (4-pack)        3.84
# 26873  AA Batteries (4-pack)         NaN
# 26874  AA Batteries (4-pack)        3.84
# 26875  AA Batteries (4-pack)        3.84

# %%
data["price_interpolation"] = data["Price Each"].interpolate()

# %%
data.loc[136303:136309,["Product","Price Each","price_interpolation"]]
# Out:
#                 Product  Price Each  price_interpolation
# 136303  ThinkPad Laptop      999.99               999.99
# 136304  ThinkPad Laptop      999.99               999.99
# 136305  ThinkPad Laptop      999.99               999.99
# 136306  ThinkPad Laptop         NaN               999.99
# 136307  ThinkPad Laptop      999.99               999.99
# 136308  ThinkPad Laptop      999.99               999.99
# 136309  ThinkPad Laptop      999.99               999.99

# %%
data[["Product","Price Each","price_interpolation"]].value_counts(dropna=False)
# Out:
# Product                     Price Each   price_interpolation
# USB-C Charging Cable        11.95        11.95                  21859
# Lightning Charging Cable    14.95        14.95                  21610
# AAA Batteries (4-pack)      2.99         2.99                   20612
# AA Batteries (4-pack)       3.84         3.84                   20557
# Wired Headphones            11.99        11.99                  18847
# Apple Airpods Headphones    150.00       150.00                 15525
# Bose SoundSport Headphones  99.99        99.99                  13298
# 27in FHD Monitor            149.99       149.99                  7498
# 27in 4K Gaming Monitor      389.99       389.99                  6225
# 34in Ultrawide Monitor      379.99       379.99                  6174
# Google Phone                600.00       600.00                  6163
# iPhone                      700.00       700.00                  5803
# Flatscreen TV               300.00       300.00                  4794
# Macbook Pro Laptop          1700.00      1700.00                 4720
# ThinkPad Laptop             999.99       999.99                  4125
# 20in Monitor                109.99       109.99                  4098
# LG Washing Machine          600.00       600.00                   666
# Google PHONE.               600.00       600.00                   664
# LG Dryer                    600.00       600.00                   646
# GOOGLE. PHONE               600.00       600.00                   616
# i-Phone                     700.00       700.00                   544
# iphone.                     700.00       700.00                   287
# I Phone                     700.00       700.00                   102
# google phoone               600.00       600.00                   102
# iphone                      700.00       700.00                    99
# Google-Phone                600.00       600.00                    24
# google phone                600.00       600.00                     8
# google Phone                600.00       600.00                     7
# IPHONE                      700.00       700.00                     4
# Wired Headphones            NaN          11.99                      2
# ASUS Gaming Laptop          4800.00      4800.00                    1
# AA Batteries (4-pack)       NaN          3.84                       1
# IPhone                      700.00       700.00                     1
# Google Phone                NaN          600.00                     1
# ThinkPad Laptop             NaN          999.99                     1
# Macbook Pro Laptop          99999999.00  99999999.00                1
# Name: count, dtype: int64

# %%
data["Price Each"] = data["price_interpolation"]

# %%
data.isnull().sum()
# Out:
# Order ID               0
# Product                0
# Quantity Ordered       0
# Price Each             0
# Order Date             0
# Street                 0
# City                   0
# State                  0
# Zip Code               0
# price_interpolation    0
# dtype: int64

# %%
data.drop(columns="price_interpolation",inplace=True)

# %% [markdown]
# ### **Update the data types of columns**

# %% [markdown]
# **Order ID**

# %%
data["Order ID"] = data["Order ID"].astype(int)

# %% [markdown]
# **Quantity Ordered**

# %%
data["Quantity Ordered"] = round(data["Quantity Ordered"])

# %%
data["Quantity Ordered"] = data["Quantity Ordered"].astype(int)

# %%
data.dtypes
# Out:
# Order ID                     int64
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Street                      object
# City                        object
# State                       object
# Zip Code                   float64
# dtype: object

# %% [markdown]
# ### **Add column: Sales**

# %%
data["Sales"] = data["Quantity Ordered"] * data["Price Each"]

# %%
data.head()
# Out:
#    Order ID       Product  Quantity Ordered  Price Each          Order Date  \
# 0    278775  20in Monitor                 1      109.99 2019-10-13 12:00:00
# 1    167149  20in Monitor                 1      109.99 2019-03-04 01:59:00
# 2    253767  20in Monitor                 1      109.99 2019-09-17 22:33:00
# 3    253776  20in Monitor                 1      109.99 2019-09-13 22:11:00
# 4    253801  20in Monitor                 1      109.99 2019-09-28 09:53:00
#
#            Street           City State  Zip Code   Sales
# 0  400 Hickory St  San Francisco    CA   94016.0  109.99
# 1   241 Meadow St  San Francisco    CA   94016.0  109.99
# 2     861 Main St        Atlanta    GA   30301.0  109.99
# 3     370 Main St    Los Angeles    CA   90001.0  109.99
# 4     446 Lake St        Seattle    WA   98101.0  109.99

# %% [markdown]
# ## Save the cleaned file

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.sort_values(by="Order ID",inplace=True)

# %%
data.to_csv("Clean_data.csv",index=False)
