# %% [markdown]
# # **Pandas**

# %% [markdown]
# Pandas is your go-to tool for handling data—cleaning, transforming, and analyzing it.
#
# With Pandas, you can:
#
# - Load data from CSVs into a DataFrame (a table-like structure).
# - Calculate statistics like mean, median, min, and max.
# - Check correlations and data distributions.
# - Clean data by removing missing values and filtering rows/columns.
# - Visualize data using Matplotlib (bar charts, histograms, etc.).
# - Save processed data back to a file.
#
# Before modeling or complex visualizations, understanding your dataset is key—Pandas makes that easy.
#
#
# https://pandas.pydata.org/docs/index.html

# %% [markdown]
# ### **Import libraries**

# %%
import pandas as pd

# %%
# help(pd)

# %% [markdown]
# ## **Creating/Reading DataFrames**

# %% [markdown]
# ### **Creating DataFrames from scratch**
#
# Creating DataFrames in Python is useful for testing Pandas methods. A simple way is using a dictionary.

# %%
data = {"Customer_ID":[1,2,3],
        "Customer_names":["Ahmad","Aliyan","Usman"],
        "Age":[23,24,25]}

# %%
data
# Out:
# {'Customer_ID': [1, 2, 3],
#  'Customer_names': ['Ahmad', 'Aliyan', 'Usman'],
#  'Age': [23, 24, 25]}

# %%
customer_data = pd.DataFrame(data)

# %%
customer_data
# Out:
#    Customer_ID Customer_names  Age
# 0            1          Ahmad   23
# 1            2         Aliyan   24
# 2            3          Usman   25

# %%
customer_data.to_csv("customer_data.csv")

# %% [markdown]
# ### **Read dataset**

# %%
# CSV, excel, json, from clipboard
pd.read_csv("/content/customer_data.csv")
# Out:
#    Unnamed: 0  Customer_ID Customer_names  Age
# 0           0            1          Ahmad   23
# 1           1            2         Aliyan   24
# 2           2            3          Usman   25

# %%
df = pd.read_csv("/content/converted_data.csv")
df
# Out:
#    order_id  customer_name product_name  quantity  order_date       city
# 0       301  Bilal Hussain       Laptop         2  2025-09-10  Islamabad
# 1       302    Maryam Shah   Smartphone         1  2025-09-11  Islamabad
# 2       303     Ahmed Khan   Headphones         4  2025-09-12  Islamabad
# 3       304   Sana Qureshi   Smartphone         3  2025-09-13  Islamabad
# 4       305    Omar Farooq       Laptop         1  2025-09-14  Islamabad

# %%
pd.read_excel("/content/converted_data.xls")
# Out:
#    order_id  customer_name product_name  quantity order_date       city
# 0       301  Bilal Hussain       Laptop         2 2025-09-10  Islamabad
# 1       302    Maryam Shah   Smartphone         1 2025-09-11  Islamabad
# 2       303     Ahmed Khan   Headphones         4 2025-09-12  Islamabad
# 3       304   Sana Qureshi   Smartphone         3 2025-09-13  Islamabad
# 4       305    Omar Farooq       Laptop         1 2025-09-14  Islamabad

# %%
# replace "edit?usp=sharing" with "export?format=csv"

# %%
url = "https://docs.google.com/spreadsheets/d/11zB2Q8-QupGoZrciiV00VC2T5PULJX7m9QP1uyjDots/export?format=csv"

# %%
data = pd.read_csv(url)

# %%
data
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234.0                      iPhone               1.0      700.00
# 1       141235.0    Lightning Charging Cable               1.0       14.95
# 2       141236.0            Wired Headphones               2.0       11.99
# 3       141237.0            27in FHD Monitor               1.0      149.99
# 4       141238.0            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185970  319666.0    Lightning Charging Cable               1.0       14.95
# 185971  319667.0       AA Batteries (4-pack)               2.0        3.84
# 185972  319668.0               Google PHONE.               1.0      600.00
# 185973  319669.0            Wired Headphones               1.0       11.99
# 185974  319670.0  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                        Purchase Address
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215
# 1       01/28/19 14:15        185 Maple St, Portland, OR 97035
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301
# ...                ...                                     ...
# 185970  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 185971  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 185972   12/09/19 6:43        273 Wilson St, Seattle, WA 98101
# 185973  12/03/19 10:39          778 River St, Dallas, TX 75001
# 185974  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [185975 rows x 6 columns]

# %% [markdown]
# ## **Explore the dataset**

# %% [markdown]
# ### **Shape of the dataset**

# %%
data.shape
# Out:
# (185975, 6)

# %% [markdown]
# ### **Top Rows**

# %%
data.head() #by default, top 5 rows
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0   141234.0                      iPhone               1.0      700.00
# 1   141235.0    Lightning Charging Cable               1.0       14.95
# 2   141236.0            Wired Headphones               2.0       11.99
# 3   141237.0            27in FHD Monitor               1.0      149.99
# 4   141238.0            Wired Headphones               1.0       11.99
# 5   141239.0      AAA Batteries (4-pack)               1.0        2.99
# 6   141240.0      27in 4K Gaming Monitor               1.0      389.99
# 7   141241.0        USB-C Charging Cable               1.0       11.95
# 8   141242.0  Bose SoundSport Headphones               1.0       99.99
# 9   141243.0    Apple Airpods Headphones               1.0      150.00
# 10  141244.0    Apple Airpods Headphones               1.0      150.00
# 11  141245.0          Macbook Pro Laptop               1.0     1700.00
# 12  141246.0      AAA Batteries (4-pack)               3.0        2.99
# 13  141247.0            27in FHD Monitor               1.0      149.99
# 14  141248.0               Flatscreen TV               1.0      300.00
# 15  141249.0            27in FHD Monitor               1.0      149.99
# 16  141250.0               Google PHONE.               1.0      600.00
# 17  141251.0    Apple Airpods Headphones               1.0      150.00
# 18  141252.0        USB-C Charging Cable               1.0       11.95
# 19  141253.0       AA Batteries (4-pack)               1.0        3.84
#
#         Order Date                         Purchase Address
# 0   01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1   01/28/19 14:15         185 Maple St, Portland, OR 97035
# 2   01/17/19 13:33    538 Adams St, San Francisco, CA 94016
# 3   01/05/19 20:33       738 10th St, Los Angeles, CA 90001
# 4   01/25/19 11:59            387 10th St, Austin, TX 73301
# 5   01/29/19 20:22   775 Willow St, San Francisco, CA 94016
# 6   01/26/19 12:16       979 Park St, Los Angeles, CA 90001
# 7   01/05/19 12:04      181 6th St, San Francisco, CA 94016
# 8   01/01/19 10:30     867 Willow St, Los Angeles, CA 90001
# 9   01/22/19 21:20  657 Johnson St, San Francisco, CA 94016
# 10  01/07/19 11:29   492 Walnut St, San Francisco, CA 94016
# 11  01/31/19 10:12      322 6th St, San Francisco, CA 94016
# 12  01/09/19 18:57        618 7th St, Los Angeles, CA 90001
# 13  01/25/19 19:19   512 Wilson St, San Francisco, CA 94016
# 14  01/03/19 21:54          363 Spruce St, Austin, TX 73301
# 15  01/05/19 17:20         440 Cedar St, Portland, OR 97035
# 16  01/10/19 11:20     471 Center St, Los Angeles, CA 90001
# 17   01/24/19 8:13          414 Walnut St, Boston, MA 02215
# 18   01/30/19 9:28        220 9th St, Los Angeles, CA 90001
# 19   01/17/19 0:09           385 11th St, Atlanta, GA 30301

# %% [markdown]
# ### **Last Rows**

# %%
data.tail(3)
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 185972  319668.0               Google PHONE.               1.0      600.00
# 185973  319669.0            Wired Headphones               1.0       11.99
# 185974  319670.0  Bose SoundSport Headphones               1.0       99.99
#
#             Order Date                        Purchase Address
# 185972   12/09/19 6:43        273 Wilson St, Seattle, WA 98101
# 185973  12/03/19 10:39          778 River St, Dallas, TX 75001
# 185974  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001

# %% [markdown]
# ### **Sample**

# %%
data.sample() #by default,it will return 1 row
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 18167  158638.0  27in 4K Gaming Monitor               1.0      389.99
#
#            Order Date              Purchase Address
# 18167  02/26/19 16:02  417 1st St, Boston, MA 02215

# %%
data.sample(5)
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 76257   214298.0  Apple Airpods Headphones               1.0      150.00
# 119904  256262.0     AA Batteries (4-pack)               1.0        3.84
# 16838   157357.0     AA Batteries (4-pack)               1.0        3.84
# 177398  311429.0    34in Ultrawide Monitor               1.0      379.99
# 180656  314556.0        Macbook Pro Laptop               1.0     1700.00
#
#             Order Date                          Purchase Address
# 76257   06/06/19 11:33    513 Forest St, San Francisco, CA 94016
# 119904  09/27/19 20:41  294 Washington St, Los Angeles, CA 90001
# 16838   02/01/19 10:12              533 2nd St, Dallas, TX 75001
# 177398  12/05/19 15:35     359 Maple St, San Francisco, CA 94016
# 180656   12/02/19 8:16            709 1st St, Portland, ME 04101

# %% [markdown]
# ### **Information about dataset**
#
#
# - Dataframe
# - Row count or number of rows
# - Column Count
# - Colum details ( index, name, non-null value_count, data type)
# - value_count of data types
# - memory_usage

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185975 entries, 0 to 185974
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185951 non-null  float64
#  1   Product           185951 non-null  object
#  2   Quantity Ordered  185901 non-null  float64
#  3   Price Each        185946 non-null  float64
#  4   Order Date        185951 non-null  object
#  5   Purchase Address  185951 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 8.5+ MB

# %% [markdown]
# errors:
# - Missing values
# - data type issue

# %% [markdown]
# ### **Statistical Summary ( descriptive statistics)**

# %%
data.describe() # by default, it will return the summary of numerical columns
# Out:
#             Order ID  Quantity Ordered    Price Each
# count  185951.000000     185901.000000  1.859460e+05
# mean   230417.792402          1.124415  7.244232e+02
# std     51512.688373          0.442846  2.319029e+05
# min    141234.000000          0.965432  2.990000e+00
# 25%    185831.500000          1.000000  1.195000e+01
# 50%    230368.000000          1.000000  1.495000e+01
# 75%    275035.500000          1.000000  1.500000e+02
# max    319670.000000          9.000000  1.000000e+08

# %%
data.describe(include="object")
# Out:
#                      Product      Order Date  \
# count                 185951          185951
# unique                    32          142396
# top     USB-C Charging Cable  12/15/19 20:16
# freq                   21903               8
#
#                               Purchase Address
# count                                   185951
# unique                                  140787
# top     193 Forest St, San Francisco, CA 94016
# freq                                         9

# %%
data.describe(include="all")
# Out:
#              Order ID               Product  Quantity Ordered    Price Each  \
# count   185951.000000                185951     185901.000000  1.859460e+05
# unique            NaN                    32               NaN           NaN
# top               NaN  USB-C Charging Cable               NaN           NaN
# freq              NaN                 21903               NaN           NaN
# mean    230417.792402                   NaN          1.124415  7.244232e+02
# std      51512.688373                   NaN          0.442846  2.319029e+05
# min     141234.000000                   NaN          0.965432  2.990000e+00
# 25%     185831.500000                   NaN          1.000000  1.195000e+01
# 50%     230368.000000                   NaN          1.000000  1.495000e+01
# 75%     275035.500000                   NaN          1.000000  1.500000e+02
# max     319670.000000                   NaN          9.000000  1.000000e+08
#
#             Order Date                        Purchase Address
# count           185951                                  185951
# unique          142396                                  140787
# top     12/15/19 20:16  193 Forest St, San Francisco, CA 94016
# freq                 8                                       9
# mean               NaN                                     NaN
# std                NaN                                     NaN
# min                NaN                                     NaN
# 25%                NaN                                     NaN
# 50%                NaN                                     NaN
# 75%                NaN                                     NaN
# max                NaN                                     NaN

# %%
a = data.describe(include="all")

# %%
a.to_csv("summary.csv")

# %% [markdown]
# ### **Check the data types**

# %% [markdown]
# ```
# "Ahmad", "[1,2,3,4]" => objects
# numeric => int 5,6,6
#         => float 5.6
#
#
#    1
#    4
#    6
#    78
#    9
#
#
#
#    9.8
#    7.8
#    5.6
#    9.0
#
#
#    "ahmad"
#    "ali"
#    "usman"
#
#
#   34
#   23
#   26
#   28
#   "27 yrs"
#
#
#
# 4
# 5
# 7
# 1
# 2
# 4.5
#
#
# 1
# 2
# 3
#
# 4
# 5
#
# IF YOU HAVE A BLANK VALUE IN A INT COLUMN, THEN IT WILL BE CONVERTED TO A FLOAT
#
#
# int => int
# int + 1 float value => float
# int/ float + object => object
# datetime / date. => date data
#
# ```

# %%
data.dtypes
# Out:
# Order ID            float64
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# ### **Column names**

# %%
#list the name of the columns in the dataset
data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# ### **Unique Values**

# %%
data['Quantity Ordered'].unique()
# Out:
# array([1.      , 2.      , 3.      , 5.      , 4.      , 7.      ,
#        6.      ,      nan, 0.965432, 9.      , 8.      ])

# %%
data['Product'].unique() #RETURNS CLASSES/ UNIQUE VALUES IN THE COLUMNS
# Out:
# array(['iPhone', 'Lightning Charging Cable', 'Wired Headphones',
#        '27in FHD Monitor', 'AAA Batteries (4-pack)',
#        '27in 4K Gaming Monitor', 'USB-C Charging Cable',
#        'Bose SoundSport Headphones', 'Apple Airpods Headphones',
#        'Macbook Pro Laptop', 'Flatscreen TV', 'Google PHONE.',
#        'AA Batteries (4-pack)', 'Google Phone', '20in Monitor',
#        '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer',
#        'LG Washing Machine', '            iPhone       ', 'GOOGLE. PHONE',
#        'IPhone', 'IPHONE', 'I Phone', 'Google-Phone', nan, 'iphone.',
#        'google phoone', 'google phone', 'iphone', 'i-Phone',
#        'google Phone', 'ASUS Gaming Laptop'], dtype=object)

# %%
data["Product"].nunique()
# Out:
# 32

# %%
data.describe(include="object")
# Out:
#                      Product      Order Date  \
# count                 185951          185951
# unique                    32          142396
# top     USB-C Charging Cable  12/15/19 20:16
# freq                   21903               8
#
#                               Purchase Address
# count                                   185951
# unique                                  140787
# top     193 Forest St, San Francisco, CA 94016
# freq                                         9

# %% [markdown]
# ### **Value counts**

# %%
data["Product"].value_counts()
# Out:
# Product
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   6169
# iPhone                         5349
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# LG Washing Machine              666
# Google PHONE.                   664
# LG Dryer                        646
# GOOGLE. PHONE                   616
# i-Phone                         544
#             iPhone              456
# iphone.                         287
# I Phone                         102
# google phoone                   102
# iphone                           99
# Google-Phone                     24
# google phone                      8
# google Phone                      7
# IPHONE                            4
# IPhone                            1
# ASUS Gaming Laptop                1
# Name: count, dtype: int64

# %%
data["Quantity Ordered"].value_counts()
# Out:
# Quantity Ordered
# 1.000000    168502
# 2.000000     13324
# 3.000000      2920
# 4.000000       806
# 5.000000       236
# 6.000000        80
# 7.000000        24
# 8.000000         5
# 9.000000         3
# 0.965432         1
# Name: count, dtype: int64

# %% [markdown]
# ### **Loc and iloc**

# %%
data["Product"]
# Out:
# 0                             iPhone
# 1           Lightning Charging Cable
# 2                   Wired Headphones
# 3                   27in FHD Monitor
# 4                   Wired Headphones
#                      ...
# 185970      Lightning Charging Cable
# 185971         AA Batteries (4-pack)
# 185972                 Google PHONE.
# 185973              Wired Headphones
# 185974    Bose SoundSport Headphones
# Name: Product, Length: 185975, dtype: object

# %% [markdown]
# #### **iLoc**
#
# - index based

# %%
data.iloc[0] # you have entered the single row_index
# Out:
# Order ID                                   141234.0
# Product                                      iPhone
# Quantity Ordered                                1.0
# Price Each                                    700.0
# Order Date                           01/22/19 21:25
# Purchase Address    944 Walnut St, Boston, MA 02215
# Name: 0, dtype: object

# %%
data.iloc[1:5]


# data.iloc[starting_index : ending_index]
# ending index will be excluded
# 5 will be excluded
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data.iloc[1:5, 0:3] #slice
# Out:
#    Order ID                   Product  Quantity Ordered
# 1  141235.0  Lightning Charging Cable               1.0
# 2  141236.0          Wired Headphones               2.0
# 3  141237.0          27in FHD Monitor               1.0
# 4  141238.0          Wired Headphones               1.0

# %%
data.iloc[[5,1000,1500], [0,1,3,5]]
# Out:
#       Order ID                 Product  Price Each  \
# 5     141239.0  AAA Batteries (4-pack)        2.99
# 1000  142192.0    USB-C Charging Cable       11.95
# 1500  142668.0  AAA Batteries (4-pack)        2.99
#
#                                 Purchase Address
# 5         775 Willow St, San Francisco, CA 94016
# 1000                68 11th St, Boston, MA 02215
# 1500  415 Washington St, San Francisco, CA 94016

# %%
data[data["Order ID"]==141238.0] #conditional statements
# Out:
#    Order ID           Product  Quantity Ordered  Price Each      Order Date  \
# 4  141238.0  Wired Headphones               1.0       11.99  01/25/19 11:59
#
#                 Purchase Address
# 4  387 10th St, Austin, TX 73301

# %% [markdown]
# #### **Loc**
#
# - Label based (column_names)

# %%
data.loc[[5,1000,1500], ["Order ID","Price Each","Purchase Address"]]
# Out:
#       Order ID  Price Each                            Purchase Address
# 5     141239.0        2.99      775 Willow St, San Francisco, CA 94016
# 1000  142192.0       11.95                68 11th St, Boston, MA 02215
# 1500  142668.0        2.99  415 Washington St, San Francisco, CA 94016

# %%
data.loc[5:10,"Order ID":"Price Each"]
#include the ending label/data
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each
# 5   141239.0      AAA Batteries (4-pack)               1.0        2.99
# 6   141240.0      27in 4K Gaming Monitor               1.0      389.99
# 7   141241.0        USB-C Charging Cable               1.0       11.95
# 8   141242.0  Bose SoundSport Headphones               1.0       99.99
# 9   141243.0    Apple Airpods Headphones               1.0      150.00
# 10  141244.0    Apple Airpods Headphones               1.0      150.00

# %% [markdown]
# loc vs iloc
#
# - both are used to fetch data
#
# - loc:
#   - label/ column name based
#   - ending values like rows/ columns are  included
#
#
# - iloc:
#   - index based
#   - ending values are not included

# %% [markdown]
# ### **Adding a column**

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data["Extra"] = "Maimoona"

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address     Extra
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  Maimoona
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035  Maimoona
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016  Maimoona
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  Maimoona
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301  Maimoona

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data["Purchase Address"].str.split(",", expand=True)
# Out:
#                       0               1          2
# 0         944 Walnut St          Boston   MA 02215
# 1          185 Maple St        Portland   OR 97035
# 2          538 Adams St   San Francisco   CA 94016
# 3           738 10th St     Los Angeles   CA 90001
# 4           387 10th St          Austin   TX 73301
# ...                 ...             ...        ...
# 185970    14 Madison St   San Francisco   CA 94016
# 185971    549 Willow St     Los Angeles   CA 90001
# 185972    273 Wilson St         Seattle   WA 98101
# 185973     778 River St          Dallas   TX 75001
# 185974  747 Chestnut St     Los Angeles   CA 90001
#
# [185975 rows x 3 columns]

# %%
data[["Street","City","State"]] = data["Purchase Address"].str.split(",", expand=True)

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address         Street  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   185 Maple St
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    738 10th St
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    387 10th St
#
#              City      State
# 0          Boston   MA 02215
# 1        Portland   OR 97035
# 2   San Francisco   CA 94016
# 3     Los Angeles   CA 90001
# 4          Austin   TX 73301

# %% [markdown]
# ```
# 944 Walnut St, Boston, MA 02215
#
# 944 Walnut St
#  Boston
#  MA 02215
#  ```

# %%
data["City"] = data["City"].str.strip(" ")

# %%
data["State"] = data["State"].str.strip(" ")

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address         Street  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   185 Maple St
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    738 10th St
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    387 10th St
#
#             City     State
# 0         Boston  MA 02215
# 1       Portland  OR 97035
# 2  San Francisco  CA 94016
# 3    Los Angeles  CA 90001
# 4         Austin  TX 73301

# %%
data[["State","Zip Code"]] = data["State"].str.split(" ",expand=True)

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address         Street  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   185 Maple St
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    738 10th St
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    387 10th St
#
#             City State Zip Code
# 0         Boston    MA    02215
# 1       Portland    OR    97035
# 2  San Francisco    CA    94016
# 3    Los Angeles    CA    90001
# 4         Austin    TX    73301

# %%
data["City"].value_counts()
# Out:
# City
# San Francisco    44732
# Los Angeles      29606
# New York City    24876
# Boston           19934
# Atlanta          14881
# Dallas           14820
# Seattle          14732
# Portland         12465
# Austin            9905
# Name: count, dtype: int64

# %% [markdown]
# ### **Dropping a column**

# %%
data.drop(columns="Purchase Address",inplace=True)

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date         Street           City State Zip Code
# 0  01/22/19 21:25  944 Walnut St         Boston    MA    02215
# 1  01/28/19 14:15   185 Maple St       Portland    OR    97035
# 2  01/17/19 13:33   538 Adams St  San Francisco    CA    94016
# 3  01/05/19 20:33    738 10th St    Los Angeles    CA    90001
# 4  01/25/19 11:59    387 10th St         Austin    TX    73301

# %%
#1st way

data = data.drop(columns="Extra")

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
# data = data without extra column

# data operation( mention inplace=True)

# %%
#2nd way: inplace

data.drop(columns="Extra",inplace=True)

# %%
data.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  141234.0                    iPhone               1.0      700.00
# 1  141235.0  Lightning Charging Cable               1.0       14.95
# 2  141236.0          Wired Headphones               2.0       11.99
# 3  141237.0          27in FHD Monitor               1.0      149.99
# 4  141238.0          Wired Headphones               1.0       11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
data.dtypes
# Out:
# Order ID            float64
# Product              object
# Quantity Ordered    float64
# Price Each          float64
# Order Date           object
# Street               object
# City                 object
# State                object
# Zip Code             object
# dtype: object

# %% [markdown]
# ### **Missing values**

# %%
data.isnull().sum()
# Out:
# Order ID            24
# Product             24
# Quantity Ordered    74
# Price Each          29
# Order Date          24
# Street              24
# City                24
# State               24
# Zip Code            24
# dtype: int64

# %% [markdown]
# ### **Duplicates**

# %%
data.duplicated().sum()
# Out:
# np.int64(289)

# %% [markdown]
# - data type issues
# - duplicates
# - missing values
# - outliers
# - text inconsistency ( iphone, IPHONE)

# %%
data.to_csv("data.csv",index=False)
